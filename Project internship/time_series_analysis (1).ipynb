# %%
# !pip install pmdarima

# %%
# !pip install nsepy

# %%
# Uninstall both packages completely
# !pip uninstall -y numpy pmdarima

# Reinstall a compatible version of numpy and then pmdarima
# !pip install numpy==1.23.5
# !pip install pmdarima
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Found existing installation: pmdarima 2.0.4
# Uninstalling pmdarima-2.0.4:
#   Successfully uninstalled pmdarima-2.0.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 73.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc 5.23.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.23.5 which is incompatible.
# xarray-einstats 0.9.0 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# albumentations 2.0.8 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
# !pip install prophet

# %%
# !pip install yfinance --quiet

# %%
# !pip install prophet plotly pandas matplotlib statsmodels

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
# Out:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 126319 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.6.0-1ubuntu1.4_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.6.0-1ubuntu1.4) ...
# Setting up libarchive-dev:amd64 (3.6.0-1ubuntu1.4) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 2.8 MB/s eta 0:00:00
# ...
#   Created wheel for libarchive: filename=libarchive-0.4.7-py3-none-any.whl size=31629 sha256=2d4b6f95c30ad3d232bb0afa25ae0f67760e4373147728a81fe34691ffef819d
#   Stored in directory: /root/.cache/pip/wheels/32/98/bd/4893d6923dd027f455b250367d402bfd69a6f4416581df46db
# Successfully built libarchive
# ...

# %%
# !apt-get -qq install -y graphviz && pip install pydot

# %%
# !pip install cartopy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 46.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pmdarima --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 15.8 MB/s eta 0:00:00

# %%
# Uninstall both packages completely
# !pip uninstall -y numpy pmdarima

# Reinstall a compatible version of numpy and then pmdarima
# Using a slightly older, stable version of numpy often helps with compatibility issues
# !pip install numpy==1.24.4
# !pip install pmdarima
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Found existing installation: pmdarima 2.0.4
# Uninstalling pmdarima-2.0.4:
#   Successfully uninstalled pmdarima-2.0.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 65.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc 5.23.0 requires numpy>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# xarray-einstats 0.9.0 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# ...

# %%
# !pip install pmdarima
# Out:
# ...
#   Using cached pmdarima-2.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# ...
# Using cached pmdarima-2.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
# ...

# %%
# !pip install nsepy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36057 sha256=7710c27f7af572cbfe13062e95c62c5be4cca1c6af92542f917bb4563f660a31
#   Stored in directory: /root/.cache/pip/wheels/94/a7/d4/0e4e94292f5761407472684b2cd74771e9985af72f968101e0
# Successfully built nsepy
# ...

# %%
# !pip uninstall -y numpy pmdarima
# Out:
# Found existing installation: numpy 1.24.4
# Uninstalling numpy-1.24.4:
#   Successfully uninstalled numpy-1.24.4
# Found existing installation: pmdarima 2.0.4
# Uninstalling pmdarima-2.0.4:
#   Successfully uninstalled pmdarima-2.0.4

# %%
# !pip install numpy==1.24.4
# !pip install pmdarima|
# Out:
# ...
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
# !pip install prophet

# %%
# !pip install yfinance --quiet

# %%
# !pip install prophet plotly pandas matplotlib statsmodels

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive

# %%
# !apt-get -qq install -y graphviz && pip install pydot

# %%
# !pip install cartopy

# %%
# !pip install pmdarima --quiet

# %%
import os
import warnings
warnings.filterwarnings('ignore')
from google.colab import files
uploaded = files.upload()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import libarchive
import pydot
import cartopy
from pylab import rcParams
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima # This import should now work after the reinstallation
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
from prophet import Prophet
from sklearn.preprocessing import MinMaxScaler
# Out:
#      <input type="file" id="files-c6438ef0-a0a2-4a46-956b-8c892d9099ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6438ef0-a0a2-4a46-956b-8c892d9099ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('GOOG.csv')

# %%
df.index = pd.to_datetime(df.index)

# %%
df = df.sort_index()

# %%
df.head()
# Out:
#                                                        Close
# 1970-01-01 00:00:00.000000000  1970-01-01 00:00:00.000000049
# 1970-01-01 00:00:00.000000001  1970-01-01 00:00:00.000000053
# 1970-01-01 00:00:00.000000002  1970-01-01 00:00:00.000000054
# 1970-01-01 00:00:00.000000003  1970-01-01 00:00:00.000000052
# 1970-01-01 00:00:00.000000004  1970-01-01 00:00:00.000000052

# %%
df.tail()
# Out:
#                                                        Close
# 1970-01-01 00:00:00.000003804  1970-01-01 00:00:00.000001219
# 1970-01-01 00:00:00.000003805  1970-01-01 00:00:00.000001205
# 1970-01-01 00:00:00.000003806  1970-01-01 00:00:00.000001176
# 1970-01-01 00:00:00.000003807  1970-01-01 00:00:00.000001187
# 1970-01-01 00:00:00.000003808  1970-01-01 00:00:00.000001209

# %%
print(df.columns)
# Out:
# Index(['Close'], dtype='object')

# %%
df.index.name = 'Date'

# %%
df['Date'] = pd.date_range(start='2020-01-01', periods=len(df), freq='D')
df.set_index('Date', inplace=True)

# %%
print(df.shape)
# Out:
# (3809, 0)

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=3809, step=1)

# %%
df.head()
# Out:
#                            Close
# 0  1970-01-01 00:00:00.000000049
# 1  1970-01-01 00:00:00.000000053
# 2  1970-01-01 00:00:00.000000054
# 3  1970-01-01 00:00:00.000000052
# 4  1970-01-01 00:00:00.000000052

# %%
df.tail()
# Out:
#                               Close
# 3804  1970-01-01 00:00:00.000001219
# 3805  1970-01-01 00:00:00.000001205
# 3806  1970-01-01 00:00:00.000001176
# 3807  1970-01-01 00:00:00.000001187
# 3808  1970-01-01 00:00:00.000001209

# %% [markdown]
# ## visualization

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Dickey-Fuller test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result = adfuller(df['Close'])

# %%
print("ADF Statistic =", test_result[0])  # ADF-test statistic
print("p-value =", test_result[1])        # p-value
print("Critical Values =", test_result[4])  # critical values
# Out:
# ADF Statistic = 0.5055143606861617
# p-value = 0.9850397406578278
# Critical Values = {'1%': -3.432081608223884, '5%': -2.862305129189198, '10%': -2.567177288520333}

# %% [markdown]
# ## we dont  have stationary value so that lets differencing

# %%
if test_result[1] > 0.05:
    print("Data is non-stationary. Applying first-order differencing...")
    df['Close_diff'] = df['Close'].diff().dropna()
else:
    print("Data is stationary. No differencing needed.")
# Out:
# Data is non-stationary. Applying first-order differencing...

# %%
if test_result[1] > 0.05:
    df_diff = df['Close'].diff().dropna()
else:
    df_diff = df['Close']

# %%
result = adfuller(df_diff)
print("ADF p-value after differencing =", result[1])
# Out:
# ADF p-value after differencing = 2.6768055337557082e-21

# %%
df = pd.read_csv('GOOG.csv', parse_dates=['Date'], index_col='Date')


df_diff = df['Close'].diff().dropna()

# %%
from statsmodels.tsa.stattools import adfuller

test_result = adfuller(df_diff)
print("ADF Statistic =", test_result[0])
print("p-value =", test_result[1])
print("Critical Values =", test_result[4])
# Out:
# ADF Statistic = -11.599016375330764
# p-value = 2.6768055337557082e-21
# Critical Values = {'1%': -3.432081608223884, '5%': -2.862305129189198, '10%': -2.567177288520333}

# %% [markdown]
# ## differenceiang

# %%
df['Sales First Difference'] = df['Close'] - df['Close'].shift(1)

# %%
df['Close'].shift(1)
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20      49.982655
# 2004-08-23      53.952770
# 2004-08-24      54.495735
# 2004-08-25      52.239193
#                  ...
# 2019-09-30    1225.089966
# 2019-10-01    1219.000000
# 2019-10-02    1205.099976
# 2019-10-03    1176.630005
# 2019-10-04    1187.829956
# Name: Close, Length: 3809, dtype: float64

# %%
print("ADF Statistic =", test_result[0])  # ADF-test statistic
print("p-value =", test_result[1])        # p-value
print("Critical Values =", test_result[4])  # critical values
# Out:
# ADF Statistic = -11.599016375330764
# p-value = 2.6768055337557082e-21
# Critical Values = {'1%': -3.432081608223884, '5%': -2.862305129189198, '10%': -2.567177288520333}

# %%
import matplotlib.pyplot as plt

# Calculate seasonal first difference with lag 12
df['Seasonal First Difference'] = df['Close'].diff(12)

# Plot the seasonal first difference
df['Seasonal First Difference'].plot()

plt.title('Seasonal First Difference of Time Series')
plt.xlabel('Date')
plt.ylabel('Seasonal First Difference')
plt.show()

# %% [markdown]
# ## removing null valu

# %%
df=df.dropna()

# %%
df.isnull().sum()    # for conferm that value are gone
# Out:
# Unnamed: 0.2                 0
# Unnamed: 0.1                 0
# Unnamed: 0                   0
# Open                         0
# High                         0
# Low                          0
# Close                        0
# Adj Close                    0
# Volume                       0
# Sales First Difference       0
# Seasonal First Difference    0
# dtype: int64

# %% [markdown]
# ## now i check my data's structure or statics

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3797 entries, 2004-09-07 to 2019-10-04
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0.2               3797 non-null   int64
#  1   Unnamed: 0.1               3797 non-null   int64
#  2   Unnamed: 0                 3797 non-null   int64
#  3   Open                       3797 non-null   float64
#  4   High                       3797 non-null   float64
#  5   Low                        3797 non-null   float64
#  6   Close                      3797 non-null   float64
#  7   Adj Close                  3797 non-null   float64
#  8   Volume                     3797 non-null   int64
#  9   Sales First Difference     3797 non-null   float64
#  10  Seasonal First Difference  3797 non-null   float64
# dtypes: float64(7), int64(4)
# memory usage: 356.0 KB
# ...

# %% [markdown]
# ## plot histo for numerical column

# %%
df['Close'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## plot a scatter plot to see  relationship

# %%
## for open vs close
import seaborn as sns
sns.scatterplot(x='Open',y='Close',data=df)
plt.title('Open vs Close')
plt.xlabel('open price')
plt.ylabel('close price')
# Out:
# Text(0, 0.5, 'close price')

# %%
stationary = df['Close'].diff().dropna()

# %% [markdown]
# # Plotting the stationary series:

# %%
import matplotlib.pyplot as plt

plt.plot(stationary)
plt.title('Stationary Time Series')
plt.xlabel('Date')
plt.ylabel('Differenced Values')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Auto Regressive Model

# %%
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot

# Plotting autocorrelation for your 'Close' column in df
autocorrelation_plot(df['Close'])

plt.title('Autocorrelation Plot of Sales')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')

# Display the plot
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plot ACF
plot_acf(stationary)
plt.title("ACF of Stationary Series")
plt.grid(True)
plt.show()

# Plot PACF
plot_pacf(stationary)
plt.title("PACF of Stationary Series")
plt.grid(True)
plt.show()

# %% [markdown]
# ## p = 1 (from PACF)
# ## d = 1 (assuming one differencing step was needed to achieve stationarity, as indicated by the "Stationary Series" titles)
# ## q = 1 (from ACF)
# ## For Non-Seasonal data

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# ## my data is a time-series with a datetime index

# %% [markdown]
# ## and we want to predict future values of 'close

# %%
df = pd.read_csv('GOOG.csv', parse_dates=['Date'], index_col='Date')

# %%
df = df.sort_index()

# %%
full_date_range = pd.date_range(start=df.index.min(),end=df.index.max(),freq='B')

# %%
model=ARIMA(df['Close'],order=(1,1,1))
model_fit=model.fit()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %% [markdown]
# # Summary of the ARIMA model

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 3809
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -13764.754
# Date:                Sat, 21 Jun 2025   AIC                          27535.509
# Time:                        22:55:42   BIC                          27554.243
# Sample:                             0   HQIC                         27542.166
#                                - 3809
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7950      0.072    -11.022      0.000      -0.936      -0.654
# ma.L1          0.8243      0.068     12.169      0.000       0.692       0.957
# sigma2        80.7622      0.531    152.088      0.000      79.721      81.803
# ...

# %% [markdown]
# # Forecast for the future (say we want 5 future points) because this is time series data for confirmation and diagnostic purposes

# %%
steps = 5
future = model_fit.forecast(steps=steps)
print("Predicted future values:")
print(future)
# Out:
# Predicted future values:
# 3809    1208.662431
# 3810    1208.930788
# 3811    1208.717452
# 3812    1208.887047
# 3813    1208.752225
# Name: predicted_mean, dtype: float64
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
import matplotlib.pyplot as plt

df['Close'].plot(figsize=(12, 8), label='Actual')
future.plot(label='Forecast')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Close price')
plt.title('Close price with forecast')
plt.show()

# %% [markdown]
# ## Generates in-sample or out-of-sample predictions for a range of index points. for diagnostics, comparison with actual data, or backtesting.

# %%
# Forecast from, say, observation 90 to 103
df['forecast'] = model_fit.predict(start=90, end=103, dynamic=True)

# %%
# Plot the actual closing price alongside the forecast
df[['Close', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Plotting the forecast alongside the historical data

# %%
ax = df['Close'].plot(label='historical closing price')
future.plot(ax=ax, label='predicted closing price')
ax.legend()

ax.set_title('ARIMA Forecast')
ax.set_xlabel('Time')
ax.set_ylabel('Close price')

plt.show()

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[df.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            Unnamed: 0.2 Unnamed: 0.1 Unnamed: 0 Open High  Low Close  \
# 2021-05-04          NaN          NaN        NaN  NaN  NaN  NaN   NaN
# 2021-06-04          NaN          NaN        NaN  NaN  NaN  NaN   NaN
# 2021-07-04          NaN          NaN        NaN  NaN  NaN  NaN   NaN
# 2021-08-04          NaN          NaN        NaN  NaN  NaN  NaN   NaN
# 2021-09-04          NaN          NaN        NaN  NaN  NaN  NaN   NaN
#
#            Adj Close Volume forecast
# 2021-05-04       NaN    NaN      NaN
# 2021-06-04       NaN    NaN      NaN
# 2021-07-04       NaN    NaN      NaN
# 2021-08-04       NaN    NaN      NaN
# 2021-09-04       NaN    NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])

# %%
future_df['forecast'] = model_fit.predict(start = 104, end = 120, dynamic= True)
future_df[['Close', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >

# %% [markdown]
# ## SARIMA

# %%
df = pd.read_csv('GOOG.csv', parse_dates=['Date'], index_col='Date')

# %%
df = df.sort_index()

# %% [markdown]
# # Confirm index is datetime

# %%
if not isinstance(df.index, pd.DatetimeIndex):
    df.index = pd.to_datetime(df.index)

# %%
ax = df['Close'].plot(title='Close price with SARIMA forecast',
                      label='historical closing price',
                      figsize=(10, 6))

# %% [markdown]
# # Set or infer frequency

# %%
if pd.infer_freq(df.index) is None:
    df = df.asfreq('D')  # Daily

# %%
model = SARIMAX(df['Close'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit = model.fit()

# %%
print(model_fit.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Close   No. Observations:                 5525
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood              -13928.842
# Date:                            Sat, 21 Jun 2025   AIC                          27867.684
# Time:                                    22:56:42   BIC                          27900.758
# Sample:                                08-19-2004   HQIC                         27879.219
#                                      - 10-04-2019
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6288      0.054     11.577      0.000       0.522       0.735
# ma.L1         -0.7079      0.049    -14.592      0.000      -0.803      -0.613
# ...

# %% [markdown]
# ##  Forecast future

# %%
model = SARIMAX(df['Close'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit = model.fit()

# %%
steps = 5
future = model_fit.forecast(steps=steps)
print("Predicted future values:")
print(future)
# Out:
# Predicted future values:
# 2019-10-05    1208.742537
# 2019-10-06    1213.859530
# 2019-10-07    1213.331108
# 2019-10-08    1214.578699
# 2019-10-09    1216.793259
# Freq: D, Name: predicted_mean, dtype: float64

# %%
future.plot(ax=ax, label='predicted closing price')
# Out:
# <Axes: title={'center': 'Close price with SARIMA forecast'}, xlabel='Date'>

# %% [markdown]
# ## Plotting forecast alongside historical data  previously i have done

# %%
ax = df['Close'].plot(title='SARIMA Forecast vs Historical Closing price',
                      label='historical closing price',
                      figsize=(10, 6))

future.plot(ax=ax, label='predicted closing price', color='red')

ax.legend()
ax.set_xlabel('Time')
ax.set_ylabel('Close price')

plt.show()

# %% [markdown]
# ## ***Applying Prophet for analyzing the future 2019-2030

# %%
data = pd.read_csv("GOOG.csv")

# %%
data.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date       Open       High  \
# 0             0             0           0  2004-08-19  49.813286  51.835709
# 1             1             1           1  2004-08-20  50.316402  54.336334
# 2             2             2           2  2004-08-23  55.168217  56.528118
# 3             3             3           3  2004-08-24  55.412300  55.591629
# 4             4             4           4  2004-08-25  52.284027  53.798351
#
#          Low      Close  Adj Close    Volume
# 0  47.800831  49.982655  49.982655  44871300
# 1  50.062355  53.952770  53.952770  22942800
# 2  54.321388  54.495735  54.495735  18342800
# 3  51.591621  52.239193  52.239193  15319700
# 4  51.746044  52.802086  52.802086   9232100

# %%
data.tail()
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date         Open  \
# 3804          3804          3804        3804  2019-09-30  1220.969971
# 3805          3805          3805        3805  2019-10-01  1219.000000
# 3806          3806          3806        3806  2019-10-02  1196.979980
# 3807          3807          3807        3807  2019-10-03  1180.000000
# 3808          3808          3808        3808  2019-10-04  1191.890015
#
#              High          Low        Close    Adj Close   Volume
# 3804  1226.000000  1212.300049  1219.000000  1219.000000  1404100
# 3805  1231.229980  1203.579956  1205.099976  1205.099976  1273500
# 3806  1196.979980  1171.290039  1176.630005  1176.630005  1615100
# 3807  1189.060059  1162.430054  1187.829956  1187.829956  1621200
# 3808  1211.439941  1189.170044  1209.000000  1209.000000  1021092

# %% [markdown]
# ## We need to convert date to date and time because date is object

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3809 entries, 0 to 3808
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  3809 non-null   int64
#  1   Unnamed: 0.1  3809 non-null   int64
#  2   Unnamed: 0    3809 non-null   int64
#  3   Date          3809 non-null   datetime64[ns]
#  4   Open          3809 non-null   float64
#  5   High          3809 non-null   float64
#  6   Low           3809 non-null   float64
#  7   Close         3809 non-null   float64
#  8   Adj Close     3809 non-null   float64
#  9   Volume        3809 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(4)
# memory usage: 297.7 KB

# %% [markdown]
# ## We plot a graph

# %%
plt.figure(figsize=(15,6))
plt.plot(data['Date'],data['Close'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## for prophet make an object which is 'model'   // make sure the date column should be 'ds' and close column should be 'y'

# %%
data.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'Date', 'Open', 'High',
#        'Low', 'Close', 'Adj Close', 'Volume'],
#       dtype='object')

# %%
df = data[['Date', 'Close']].copy()

# %%
df.columns = ['ds', 'y']

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
model = Prophet()
model.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp470m5yl9/9h9z9piy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp470m5yl9/8g8tixu6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37404', 'data', 'file=/tmp/tmp470m5yl9/9h9z9piy.json', 'init=/tmp/tmp470m5yl9/8g8tixu6.json', 'output', 'file=/tmp/tmp470m5yl9/prophet_modelvylvbkbi/prophet_model-20250621225737.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:57:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:57:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# ## Create future dataframe. There is a function make_future_dataframe

# %%
future = model.make_future_dataframe(periods=4106,freq='D')
forecast = model.predict(future)
forecast.tail()
# Out:
#              ds        trend  yhat_lower   yhat_upper  trend_lower  \
# 7910 2030-12-27  2913.763000  506.120517  5246.347853   505.854077
# 7911 2030-12-28  2914.168381  515.953018  5245.276939   505.311310
# 7912 2030-12-29  2914.573762  519.724115  5252.014582   504.768543
# 7913 2030-12-30  2914.979143  524.928940  5263.252870   504.225776
# 7914 2030-12-31  2915.384524  509.559021  5289.285485   503.683008
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 7910  5231.484327        9.476484              9.476484              9.476484
# 7911  5233.097233        5.589452              5.589452              5.589452
# 7912  5234.710139        5.657149              5.657149              5.657149
# 7913  5236.323045        9.222645              9.222645              9.222645
# 7914  5237.935951        9.971393              9.971393              9.971393
#
#         weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# ...

# %% [markdown]
# ## We are currently checking how many stocks closed on a particular day.
# ## But instead, we want to check how many stocks will close up to 2030-12-31

# %%
forecast['yhat'].sum()
# Out:
# 10371581.82135571

# %% [markdown]
# ## the no is 10378306.050100667

# %%
from prophet.plot import plot_plotly, plot_components_plotly
plot_plotly(model, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## for weekly & monthly gaind

# %%
plot_components_plotly(model,forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## ***Implement Of LSTM

# %%
import pandas as pd
df = pd.read_csv('GOOG.csv')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'Date', 'Open', 'High',
#        'Low', 'Close', 'Adj Close', 'Volume'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date       Open       High  \
# 0             0             0           0  2004-08-19  49.813286  51.835709
# 1             1             1           1  2004-08-20  50.316402  54.336334
# 2             2             2           2  2004-08-23  55.168217  56.528118
# 3             3             3           3  2004-08-24  55.412300  55.591629
# 4             4             4           4  2004-08-25  52.284027  53.798351
#
#          Low      Close  Adj Close    Volume
# 0  47.800831  49.982655  49.982655  44871300
# 1  50.062355  53.952770  53.952770  22942800
# 2  54.321388  54.495735  54.495735  18342800
# 3  51.591621  52.239193  52.239193  15319700
# 4  51.746044  52.802086  52.802086   9232100

# %%
df.tail()
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date         Open  \
# 3804          3804          3804        3804  2019-09-30  1220.969971
# 3805          3805          3805        3805  2019-10-01  1219.000000
# 3806          3806          3806        3806  2019-10-02  1196.979980
# 3807          3807          3807        3807  2019-10-03  1180.000000
# 3808          3808          3808        3808  2019-10-04  1191.890015
#
#              High          Low        Close    Adj Close   Volume
# 3804  1226.000000  1212.300049  1219.000000  1219.000000  1404100
# 3805  1231.229980  1203.579956  1205.099976  1205.099976  1273500
# 3806  1196.979980  1171.290039  1176.630005  1176.630005  1615100
# 3807  1189.060059  1162.430054  1187.829956  1187.829956  1621200
# 3808  1211.439941  1189.170044  1209.000000  1209.000000  1021092

# %%
df2 = df.reset_index()[['Close']]

# %%
df.shape
# Out:
# (3809, 10)

# %%
df
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date         Open  \
# 0                0             0           0  2004-08-19    49.813286
# 1                1             1           1  2004-08-20    50.316402
# 2                2             2           2  2004-08-23    55.168217
# 3                3             3           3  2004-08-24    55.412300
# 4                4             4           4  2004-08-25    52.284027
# ...            ...           ...         ...         ...          ...
# 3804          3804          3804        3804  2019-09-30  1220.969971
# 3805          3805          3805        3805  2019-10-01  1219.000000
# 3806          3806          3806        3806  2019-10-02  1196.979980
# 3807          3807          3807        3807  2019-10-03  1180.000000
# 3808          3808          3808        3808  2019-10-04  1191.890015
#
#              High          Low        Close    Adj Close    Volume
# ...

# %%
plt.plot(df['Close'])
plt.xlabel('Index')
plt.ylabel('Close Price')
plt.title('Stock Price Over Time')
plt.grid(True)
plt.show()

# %%
df.head()
df.dtypes
# Out:
# Unnamed: 0.2      int64
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Adj Close       float64
# Volume            int64
# dtype: object

# %%
# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Convert Close column to numeric (float)
df['Close'] = pd.to_numeric(df['Close'], errors='coerce')

# %%
df.head()
df.dtypes
# Out:
# Unnamed: 0.2             int64
# Unnamed: 0.1             int64
# Unnamed: 0               int64
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Stock Closing Price Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## ***Implementation of LSTM (Long Short-Term Memory)

# %%
### Data Collection
import pandas_datareader as pdr
key=""

# %%
df.to_csv('GOOG.csv')

# %%
df=pd.read_csv('GOOG.csv')

# %%
print(df.head())
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date  \
# 0             0             0             0           0  2004-08-19
# 1             1             1             1           1  2004-08-20
# 2             2             2             2           2  2004-08-23
# 3             3             3             3           3  2004-08-24
# 4             4             4             4           4  2004-08-25
#
#         Open       High        Low      Close  Adj Close    Volume
# 0  49.813286  51.835709  47.800831  49.982655  49.982655  44871300
# 1  50.316402  54.336334  50.062355  53.952770  53.952770  22942800
# 2  55.168217  56.528118  54.321388  54.495735  54.495735  18342800
# 3  55.412300  55.591629  51.591621  52.239193  52.239193  15319700
# 4  52.284027  53.798351  51.746044  52.802086  52.802086   9232100

# %%
df.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date  \
# 0             0             0             0           0  2004-08-19
# 1             1             1             1           1  2004-08-20
# 2             2             2             2           2  2004-08-23
# 3             3             3             3           3  2004-08-24
# 4             4             4             4           4  2004-08-25
#
#         Open       High        Low      Close  Adj Close    Volume
# 0  49.813286  51.835709  47.800831  49.982655  49.982655  44871300
# 1  50.316402  54.336334  50.062355  53.952770  53.952770  22942800
# 2  55.168217  56.528118  54.321388  54.495735  54.495735  18342800
# 3  55.412300  55.591629  51.591621  52.239193  52.239193  15319700
# 4  52.284027  53.798351  51.746044  52.802086  52.802086   9232100

# %%
df.tail()
# Out:
#       Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        Date  \
# 3804          3804          3804          3804        3804  2019-09-30
# 3805          3805          3805          3805        3805  2019-10-01
# 3806          3806          3806          3806        3806  2019-10-02
# 3807          3807          3807          3807        3807  2019-10-03
# 3808          3808          3808          3808        3808  2019-10-04
#
#              Open         High          Low        Close    Adj Close   Volume
# 3804  1220.969971  1226.000000  1212.300049  1219.000000  1219.000000  1404100
# 3805  1219.000000  1231.229980  1203.579956  1205.099976  1205.099976  1273500
# 3806  1196.979980  1196.979980  1171.290039  1176.630005  1176.630005  1615100
# 3807  1180.000000  1189.060059  1162.430054  1187.829956  1187.829956  1621200
# 3808  1191.890015  1211.439941  1189.170044  1209.000000  1209.000000  1021092

# %%
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df=df.reset_index()['Close']

# %%
df
# Out:
# 0         49.982655
# 1         53.952770
# 2         54.495735
# 3         52.239193
# 4         52.802086
#            ...
# 3804    1219.000000
# 3805    1205.099976
# 3806    1176.630005
# 3807    1187.829956
# 3808    1209.000000
# Name: Close, Length: 3809, dtype: float64

# %%
plt.plot(df)

# %% [markdown]
# ### LSTM are sensitive to the scale of the data. so we apply MinMax scaler

# %%
df
# Out:
# 0         49.982655
# 1         53.952770
# 2         54.495735
# 3         52.239193
# 4         52.802086
#            ...
# 3804    1219.000000
# 3805    1205.099976
# 3806    1176.630005
# 3807    1187.829956
# 3808    1209.000000
# Name: Close, Length: 3809, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
print(df)
# Out:
# [[1.32809895e-04]
#  [3.34030536e-03]
#  [3.77897219e-03]
#  ...
#  [9.10362429e-01]
#  [9.19410981e-01]
#  [9.36514471e-01]]

# %% [markdown]
# ##splitting dataset into train and test spli

# %%
## we are using 75% for training size and the rest of the 25% will be test size
training_size=int(len(df)*0.75)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (2856, 953)

# %%
train_data
# Out:
# array([[1.32809895e-04],
#        [3.34030536e-03],
#        [3.77897219e-03],
#        ...,
#        [5.65223283e-01],
#        [5.57047238e-01],
#        [5.63882174e-01]])

# %% [markdown]
# # convert an array of values into a dataset matrix

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# # reshape into X=t,t+1,t+2,t+3 and Y=t+4

# %%
import numpy as np
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (2755, 100)
# (2755,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (852, 100)
# (852,)
# (None, None)

# %% [markdown]
# ## reshape input to be [samples, time steps, features] which is required for LSTM

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# ### Now Create the Stacked LSTM model

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.26.4
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.19.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.19.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.19.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip install --upgrade tensorflow
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 447, in run
# ^C

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_9 (LSTM)                   │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 100, 50)        │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,851 (198.64 KB)
#  Trainable params: 50,851 (198.64 KB)
# ...

# %%
model.fit(X_train, y_train, validation_data=(X_test, ytest), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - loss: 0.0138 - val_loss: 0.0018
# Epoch 2/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - loss: 3.6542e-04 - val_loss: 0.0014
# Epoch 3/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 11s 186ms/step - loss: 1.8230e-04 - val_loss: 0.0010
# Epoch 4/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - loss: 1.9060e-04 - val_loss: 8.5017e-04
# Epoch 5/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - loss: 2.0410e-04 - val_loss: 0.0014
# Epoch 6/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - loss: 1.7754e-04 - val_loss: 7.9735e-04
# Epoch 7/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - loss: 1.7379e-04 - val_loss: 0.0012
# Epoch 8/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - loss: 1.6525e-04 - val_loss: 0.0015
# Epoch 9/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 8s 182ms/step - loss: 1.5377e-04 - val_loss: 0.0011
# Epoch 10/100
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 9s 150ms/step - loss: 1.6624e-04 - val_loss: 0.0013
# Epoch 11/100
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.19.0'

# %% [markdown]
# ### Lets Do the prediction and check performance metrics

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step

# %% [markdown]
# ##Transformback to original form

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Now we Calculate RMSE performance metrics

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 353.1150474731744

# %% [markdown]
# ## Test Data RMSE(Root Mean Squared Error)

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 1002.9616590202257

# %% [markdown]
# ### Plotting

# %%
# shift train predictions for plotting
look_back=100
trainPredictPlot = np.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# ## TO get the number of data points (i.e., the length) in the test dataset.

# %%
len(test_data)
# Out:
# 953

# %% [markdown]
# ## prepare the input for making future predictions using a model like LSTM or any sequence-based neural network, especially after training.

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 612)

# %% [markdown]
# ## for loop base prediction process

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.7001523333625753,
#  0.708716159584348,
#  0.7124486995755196,
#  0.7087888932946194,
#  0.7145815939974384,
#  0.7128607417359326,
#  0.7101219641240019,
#  0.7115923174380883,
#  0.712901127539181,
#  0.716827607124967,
#  0.7216104203735865,
#  0.7027214813906891,
#  0.7113014811620183,
#  0.7143473178820832,
#  0.7206893908967071,
#  0.7263124620157091,
#  0.7312730413093864,
#  0.7430523330271311,
#  0.7446115936010453,
#  0.7481745040084,
#  0.739271320053978,
#  0.7409598736909685,
#  0.7479482657892703,
#  0.7544761920276853,
#  0.7487319634989381,
#  0.7522625259992697,
#  0.754258040179379,
#  0.7271284591578019,
#  0.7215296487670896,
#  0.7300127033823655,
#  0.7278798097683565,
#  0.7210529608830484,
#  0.7190089737209575,
#  0.7332200825075141,
#  0.72777477743357,
#  0.7349005489657715,
#  0.7329938935708922,
#  0.7398611282594488,
#  0.7290997618921292,
#  0.7089504849822108,
#  0.7195825582864542,
#  0.7012429924232717,
#  0.6939233297710535,
# ...

# %% [markdown]
# ## Let's generate 30 future predictions one at a time using the already trained LSTM model

# %%
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):

    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1


print(lst_output)
# Out:
# 0 day input [0.70871616 0.7124487  0.70878889 0.71458159 0.71286074 0.71012196
#  0.71159232 0.71290113 0.71682761 0.72161042 0.70272148 0.71130148
#  0.71434732 0.72068939 0.72631246 0.73127304 0.74305233 0.74461159
#  0.7481745  0.73927132 0.74095987 0.74794827 0.75447619 0.74873196
#  0.75226253 0.75425804 0.72712846 0.72152965 0.7300127  0.72787981
#  0.72105296 0.71900897 0.73322008 0.72777478 0.73490055 0.73299389
#  0.73986113 0.72909976 0.70895048 0.71958256 0.70124299 0.69392333
#  0.68582002 0.69633094 0.69227521 0.70188936 0.71013809 0.71118032
#  0.722281   0.7249713  0.73210516 0.73002883 0.73970762 0.74414304
#  0.74192938 0.74578307 0.7517778  0.72783134 0.72548838 0.71441196
#  0.72042282 0.71151155 0.71177817 0.71142269 0.70597738 0.70945947
#  0.71059052 0.70851418 0.70537145 0.69271955 0.69849613 0.7051856
#  0.70482203 0.70865156 0.69574113 0.69549068 0.69225095 0.70681759
#  0.70868386 0.70406264 0.69970799 0.69802753 0.70407068 0.7107602
# ...

# %% [markdown]
# ## prepare the X-axis (days) for plotting ->
# ## The last 100 known data points (day_new)
# ## the next 30 predicted future points (day_pred)

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
len(df)
# Out:
# 3809

# %% [markdown]
# ## Convert to numpy array and reshape

# %%
df1 = df.reshape(-1, 1)  # if df is already a NumPy array

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(df)

# %%
day_new = np.arange(1, 101)       # Last 100 days
day_pred = np.arange(101, 131)    # Next 30 predicted days

# %% [markdown]
# ## for last 100 knows value

# %%
last_100 = data_scaled[-100:]

# %%
future_predictions = np.array(lst_output).reshape(-1, 1)

# %% [markdown]
# ## for result plot

# %%
plt.figure(figsize=(10, 6))
plt.plot(day_new, scaler.inverse_transform(last_100), label='Past 100 Days')
plt.plot(day_pred, scaler.inverse_transform(future_predictions), label='Next 30 Day Forecast', color='red')
plt.title("Stock Price Forecast (Next 30 Days)")
plt.xlabel("Day")
plt.ylabel("Stock Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
df3 = df1.tolist()
df3.extend(lst_output)

# Flatten the list safely
df3_flat = [item[0] if isinstance(item, (list, np.ndarray)) else item for item in df3]

plt.figure(figsize=(10, 6))
plt.plot(df3_flat[1200:])
plt.title("Stock Price Forecast (Past + Future)")
plt.xlabel("Days")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %%
flat_df3 = []

for item in df3:
    if isinstance(item, list) or isinstance(item, np.ndarray):
        flat_df3.append(item[0])  # Get the first element if it's a list or array
    else:
        flat_df3.append(item)

# %% [markdown]
# ##  Now convert to 2D array

# %%
df3_array = np.array(flat_df3).reshape(-1, 1)

# %% [markdown]
# ## Inverse transform

# %%
df3_inverse = scaler.inverse_transform(df3_array)

# %% [markdown]
# ## now  Flatten to list again

# %%
df3 = df3_inverse.flatten().tolist()

# %%
plt.plot(df3)
